一門學問，我總是喜愛捧著那一卷卷泛黃書冊，翻出一頁頁盛世繁華，感嘆一段段生死契闊弦斷聲啞。看著書中所闡述的一場場涅槃順變顏色、抬眼間已換了山河的沙場明征、廟堂暗鬥總是令我為之著迷不已，多希望能置身當中和歷代英傑千里逐鹿中原，對酒笑談江山。曾經，我天真的以為自己已經尋得了泱泱歷史上所有的精華，竟妄以為古今之事僅以紙上寥寥數筆便能完全了然於心。直到有次拜讀柏楊版《資治通鑑》時，看見了柏老對於歷代功過是非有著顛覆傳統但言辭依舊犀利精準的評判，我才赫然發現歷史的真諦竟是隱隱藏匿於字裡間的永世不滅。相較於書中讚譽之詞盈溢的千古一帝，背後辛勤維持江山社稷的芸芸眾生才更令人敬佩膺服；相較於驍勇躍然於紙上的萬世名將，火光淒厲的烽燧斷刃旁靜躺的森森白骨卻是淪為青史中遺留的殘殤無人憑弔。曾幾何時，我們總對於自己的執念深信不已，不過尋到了一閃微光，卻以為得到了整片宇宙。屈原《離騷》云：「路漫漫其修遠兮，吾將上下而求索。」尋，是人生中必然的抉擇，縱然結果茫不可測，卻也最是令人著迷。尋，可竭盡全力亦或閒適顧盼，若能承受路途上的滿道荊棘，得到後的滋味固然鮮美，倘若到不了心中期望的沃野，峰迴路轉中亦能尋見意外的桃花源，驀然回首燈火闌珊處，前程往事何不能皆附以一笑置之"
cutter <- worker(bylines = F)

# %%
cutter[content]
# Out:
#   [1] "昔"             "我"             "往"             "矣"
#   [5] "楊柳依依"       "今"             "我"             "來"
#   [9] "思"             "雨雪霏霏"       "時光"           "輾轉"
#  [13] "成歌"           "歲月流逝"       "如花"           "陌上"
#  [17] "煙涼"           "荼靡"           "了"             "幾季"
#  [21] "晨昏"           "時間"           "總是"           "在"
#  [25] "不經意"         "之中"           "悄然"           "流逝"
#  [29] "如同"           "一縷"           "裊裊"           "輕煙"
#  [33] "如此"           "飄渺"           "倏忽"           "又"
#  [37] "總是"           "稍縱即逝"       "當你想"         "用"
#  [41] "雙手"           "將它"           "緊緊"           "握住"
#  [45] "時"             "一"             "攤開"           "卻"
#  [49] "發現"           "僅剩"           "滿掌"           "虛無"
#  [53] "大千世界"       "太廣"           "生命"           "時間"
#  [57] "太短"           "有人"           "如愷愷"         "白雪"
#  [61] "般"             "清心"           "淡泊"           "一生"
#  [65] "有人"           "卻是"           "於"             "汲汲營營"
# ...

# %%
new_words <- c("滄海一粟","千古一帝")
for(i in 1:length(new_words)){
  new_user_word(cutter,new_words[i])
}
content <- str_remove_all(content,"[0-9a-zA-Z]+?")
cutter[content]
# Out:
#   [1] "昔"             "我"             "往"             "矣"
#   [5] "楊柳依依"       "今"             "我"             "來"
#   [9] "思"             "雨雪霏霏"       "時光"           "輾轉"
#  [13] "成歌"           "歲月流逝"       "如花"           "陌上"
#  [17] "煙涼"           "荼靡"           "了"             "幾季"
#  [21] "晨昏"           "時間"           "總是"           "在"
#  [25] "不經意"         "之中"           "悄然"           "流逝"
#  [29] "如同"           "一縷"           "裊裊"           "輕煙"
#  [33] "如此"           "飄渺"           "倏忽"           "又"
#  [37] "總是"           "稍縱即逝"       "當你想"         "用"
#  [41] "雙手"           "將它"           "緊緊"           "握住"
#  [45] "時"             "一"             "攤開"           "卻"
#  [49] "發現"           "僅剩"           "滿掌"           "虛無"
#  [53] "大千世界"       "太廣"           "生命"           "時間"
#  [57] "太短"           "有人"           "如愷愷"         "白雪"
#  [61] "般"             "清心"           "淡泊"           "一生"
#  [65] "有人"           "卻是"           "於"             "汲汲營營"
# ...

# %%
new_words <- c("滄海一粟","千古一帝")
writeLines(new_words , "new_words.txt")

stop_words <- c("昔","我","往","矣","中","的","云","於","為","了","也","卻","在","他","但")
writeLines(stop_words , "stop_words.txt")
cutter <-worker(user = "new_word.txt",stop_word="stop_words.txt",
bylines=FALSE)

seg_words<- cutter[content]
seg_words
# Out:
#   [1] "楊柳依依"       "今"             "來"             "思"
#   [5] "雨雪霏霏"       "時光"           "輾轉"           "成歌"
#   [9] "歲月流逝"       "如花"           "陌上"           "煙涼"
#  [13] "荼靡"           "幾季"           "晨昏"           "時間"
#  [17] "總是"           "不經意"         "之中"           "悄然"
#  [21] "流逝"           "如同"           "一縷"           "裊裊"
#  [25] "輕煙"           "如此"           "飄渺"           "倏忽"
#  [29] "又"             "總是"           "稍縱即逝"       "當你想"
#  [33] "用"             "雙手"           "將它"           "緊緊"
#  [37] "握住"           "時"             "一"             "攤開"
#  [41] "發現"           "僅剩"           "滿掌"           "虛無"
#  [45] "大千世界"       "太廣"           "生命"           "時間"
#  [49] "太短"           "有人"           "如愷愷"         "白雪"
#  [53] "般"             "清心"           "淡泊"           "一生"
#  [57] "有人"           "卻是"           "汲汲營營"       "沉淪"
#  [61] "掙扎"           "一世"           "我們"           "同"
#  [65] "屬於"           "滄海"           "一粟"           "這個"
# ...

# %%
txt_freq <- freq(seg_words)

txt_freq <- arrange(txt_freq,desc(freq))

head(txt_freq)
# Out:
#   char freq
# 1 總是 4
# 2 令人 4
# 3 尋   4
# 4 上   3
# 5 卻是 3
# 6 最後 3

# %%
install.packages("showtext")
library(showtext)
showtext.auto(enable = TRUE)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘sysfonts’, ‘showtextdb’
#
#
# Loading required package: sysfonts
#
# Loading required package: showtextdb
#
# 'showtext.auto()' is now renamed to 'showtext_auto()'
# The old version still works, but consider using the new function in future code

# %%
par(family=("Microsoft YaHei"))
wordcloud(txt_freq$char, txt_freq$freq,min.freq=2,random.order=F,
ordered.colors=F,colors=rainbow(nrow(txt_freq)))
# Out:
# Warning message in strwidth(words[i], cex = size[i], ...):
# “font family 'Microsoft YaHei' not found, will use 'wqy-microhei' instead”
# Warning message in strheight(words[i], cex = size[i], ...):
# “font family 'Microsoft YaHei' not found, will use 'sans' instead”
# Warning message in text.default(x1, y1, words[i], cex = size[i], offset = 0, srt = rotWord * :
# “font family 'Microsoft YaHei' not found, will use 'wqy-microhei' instead”
# Warning message in text.default(x1, y1, words[i], cex = size[i], offset = 0, srt = rotWord * :
# “font family 'Microsoft YaHei' not found, will use 'wqy-microhei' instead”
# Warning message in text.default(x1, y1, words[i], cex = size[i], offset = 0, srt = rotWord * :
# “font family 'Microsoft YaHei' not found, will use 'wqy-microhei' instead”
# Warning message in text.default(x1, y1, words[i], cex = size[i], offset = 0, srt = rotWord * :
# “font family 'Microsoft YaHei' not found, will use 'wqy-microhei' instead”
# ...

# %%
wordcould2(txt_freq)
# Out:
# Error in wordcould2(txt_freq): could not find function "wordcould2"
# Traceback:
