# %% [markdown]
# <a href="https://colab.research.google.com/github/jaham954012/bigdata/blob/main/asisment6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
install.packages("ggplot2")
library(ggplot2)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
install.packages("SportsAnalytics")
library(SportsAnalytics)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
NBA1314 <- fetch_NBAPlayerStatistics("13-14")
qplot(FieldGoalsAttempted , TotalPoints , data= NBA1314 , color=Position)
# Out:
# plot without title

# %%
qplot(FieldGoalsAttempted , TotalPoints , data= NBA1314 , color=Position,geom=c("smooth"))
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
qplot(TotalMinutesPlayed  , Blocks  , data= NBA1314 , color=Position)
# Out:
# plot without title

# %%
qplot(TotalMinutesPlayed  , Blocks  , data= NBA1314 , color=Position,geom=c("smooth"))
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
ggplot(NBA1314,aes(x=TotalMinutesPlayed ,y=TotalPoints,color=Position))+geom_line()
# Out:
# plot without title
